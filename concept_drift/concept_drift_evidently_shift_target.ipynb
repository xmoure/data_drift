# %%
import pandas as pd
from tensorflow.keras.models import load_model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from evidently.report import Report
from evidently.metric_preset import ClassificationPreset
import os
import cv2
import numpy as np
import mlflow
from scipy.stats import wasserstein_distance

# %%
# Set MLflow experiment name
mlflow.set_experiment("Concept Drift Detection")
# Out:
# <Experiment: artifact_location='file:///Users/ximenamoure/Desktop/concept_drift/mlruns/457136894682190825', creation_time=1728658822037, experiment_id='457136894682190825', last_update_time=1728658822037, lifecycle_stage='active', name='Concept Drift Detection', tags={}>

# %%
model = load_model('/Users/ximenamoure/Desktop/drift_last/models/mobilenet_v2_occupancy_tf216.keras')

# %%
ref_path = "/Users/ximenamoure/Desktop/drift_last/reference_dataset"

# %%
new_path = "/Users/ximenamoure/Chess-Piece-Classification-Dataset/images/processed/occupancy/split0"

# %%
#split_name = os.path.basename(new_path)

# %%
categories = ["bb", "bk", "bn", "bp", "bq", "br", "wb", "wk", "wn", "wp", "wq", "wr", "empty"]

# %%
label_mapping = {category: 1 for category in categories if category != "empty"}
label_mapping["empty"] = 0

# %%
new_label_mapping = {
    "wb": 1, "wk": 1, "wn": 1, "wp": 1, "wq": 1, "wr": 1,  # White pieces marked as "occupied" (1)
    "bb": 0, "bk": 0, "bn": 0, "bp": 0, "bq": 0, "br": 0,  # Black pieces marked as "empty" (0)
    "empty": 0  # Keep empty squares as "empty" (0)
}

# %%
def load_images_and_labels_with_new_interpretation(base_path, categories, label_mapping):
    images = []
    labels = []
    image_paths = []

    for category in categories:
        category_path = os.path.join(base_path, category)
        for img_name in os.listdir(category_path):
            img_path = os.path.join(category_path, img_name)
            img = cv2.imread(img_path)
            img = cv2.resize(img, (128, 128))
            images.append(img)
            labels.append(label_mapping[category])
            image_paths.append(img_path)

    return np.array(images), np.array(labels), np.array(image_paths)

# %%
# Function to load images and their labels
def load_images_and_labels(base_path, categories):
    images = []
    labels = []
    image_paths = []

    for category in categories:
        category_path = os.path.join(base_path, category)
        for img_name in os.listdir(category_path):
            img_path = os.path.join(category_path, img_name)
            img = cv2.imread(img_path)
            img = cv2.resize(img, (128, 128))
            images.append(img)
            labels.append(label_mapping[category])
            image_paths.append(img_path)


    return np.array(images), np.array(labels), np.array(image_paths)

# %%
def get_model_predictions(model, images, batch_size=32, threshold = 0.5):
    num_images = len(images)
    predictions = []

    # Process in batches
    for start in range(0, num_images, batch_size):
        end = min(start + batch_size, num_images)
        batch_images = images[start:end]
        batch_predictions = model.predict(batch_images)
        print("predictions", batch_predictions)

        # Convert probabilities to binary labels based on threshold
        batch_labels = (batch_predictions >= threshold).astype(int)

        # Flatten the array and add to the list of predictions
        predictions.extend(batch_labels.flatten())
        print(f"Processed {end}/{num_images} images ({(end / num_images) * 100:.2f}% complete)")

    return np.array(predictions)

# %%
def get_model_scores(model, images, batch_size=32):
    num_images = len(images)
    scores = []
    for start in range(0, num_images, batch_size):
        end = min(start + batch_size, num_images)
        batch_images = images[start:end]
        batch_scores = model.predict(batch_images)
        scores.extend(batch_scores.flatten())

        print(f"Processed {end}/{num_images} images ({(end / num_images) * 100:.2f}% complete)")

    return np.array(scores)

# %%
def get_metrics(ground_truth, predictions):
    accuracy = accuracy_score(ground_truth, predictions)
    precision = precision_score(ground_truth, predictions)
    recall = recall_score(ground_truth, predictions)
    f1 = f1_score(ground_truth, predictions)
    return accuracy, precision, recall, f1

# %%
# Function to calculate batch-wise error rates
def batch_error_rates(model, images, labels, batch_size=32):
    batch_errors = []
    for start in range(0, len(images), batch_size):
        end = min(start + batch_size, len(images))
        batch_images = images[start:end]
        batch_labels = labels[start:end]

        # Get predictions for the batch
        batch_preds = model.predict(batch_images)
        batch_preds = (batch_preds >= 0.5).astype(int).flatten()

        # Calculate error rate for this batch
        incorrect = np.sum(batch_preds != batch_labels)
        error_rate = incorrect / len(batch_labels)
        batch_errors.append(error_rate)

    return batch_errors

# %%
images_ref, labels_ref, img_paths_ref = load_images_and_labels(ref_path, categories)

# %%
images, drifted_labels, image_paths = load_images_and_labels_with_new_interpretation(ref_path, categories, new_label_mapping)

# %%
""" images_new, labels_new, img_paths_new = load_images_and_labels(new_path, categories) """
# Out:
# ' images_new, labels_new, img_paths_new = load_images_and_labels(new_path, categories) '

# %%
model = load_model('/Users/ximenamoure/Desktop/drift_last/models/mobilenet_v2_occupancy_tf216.keras')

# %%
split_name = "ref_split_target_shifted"

# %%
accuracy_drop_threshold = 0.1 # for a 10% decrease
f1_drop_threshold = 0.1 # for a 10% decrease

# %%
ws_threshold = 0.12

# %%
# --- Start MLflow Run ---
with mlflow.start_run() as run:
    mlflow.set_tag("mlflow.runName", "shift_in_target_variable")
    print("Processing and logging reference split...")
    images_ref, labels_ref, img_paths_ref = load_images_and_labels(ref_path, categories)
    predictions_ref = get_model_predictions(model, images_ref)
    batch_errors_ref = batch_error_rates(model, images_ref, labels_ref)
    accuracy_ref, precision_ref, recall_ref, f1_ref = get_metrics(labels_ref, predictions_ref)

    # Log reference metrics and batch errors as an artifact
    mlflow.log_metrics({
        "accuracy_ref": accuracy_ref,
        "precision_ref": precision_ref,
        "recall_ref": recall_ref,
        "f1_ref": f1_ref
    })
    images_new = images_ref
    labels_new = drifted_labels
    predictions_new = get_model_predictions(model, images_new)
    batch_errors_new = batch_error_rates(model, images_new, labels_new)
    accuracy_new, precision_new, recall_new, f1_new = get_metrics(labels_new, predictions_new)
    # Log new split metrics and error rates to MLflow
    mlflow.log_metrics({
            f"{split_name}_accuracy": accuracy_new,
            f"{split_name}_precision": precision_new,
            f"{split_name}_recall": recall_new,
            f"{split_name}_f1": f1_new
    })

    # --- Long-Term Drift Detection with Reference Split ---
    wd_ref = wasserstein_distance(batch_errors_ref, batch_errors_new)
    # Detect drift based on threshold
    drift_detected_ref = wd_ref > ws_threshold

    print("drfit_detected", drift_detected_ref)

    mlflow.log_metric(f"{split_name}_wasserstein_distance_ref", wd_ref)
    mlflow.log_metric(f"{split_name}_drift_detected_ref", int(drift_detected_ref))

    #--- Generate and Log Evidently Report ---
    reference_data = pd.DataFrame({'prediction': predictions_ref, 'target': labels_ref, 'dataset': 'reference'})
    new_data = pd.DataFrame({'prediction': predictions_new, 'target': labels_new, 'dataset': 'new'})
    classification_report = Report(metrics=[ClassificationPreset()])
    classification_report.run(reference_data=reference_data, current_data=new_data)

    # Save and log the Evidently report
    report_file = f"{split_name}_classification_report.html"
    classification_report.save_html(report_file)
    mlflow.log_artifact(report_file)

    results = classification_report.as_dict()
    current_metrics = results["metrics"][0]["result"]["current"]
    reference_metrics = results["metrics"][0]["result"]["reference"]
    accuracy_current = current_metrics["accuracy"]
    f1_current = current_metrics["f1"]
    recall_current = current_metrics["recall"]
    accuracy_reference = reference_metrics["accuracy"]
    f1_reference = reference_metrics["f1"]

    accuracy_significant_drop = (accuracy_reference - accuracy_current) > (accuracy_reference * accuracy_drop_threshold)
    f1_significant_drop = (f1_reference - f1_current) > (f1_reference * f1_drop_threshold)
    print("Significant Accuracy Drop:", accuracy_significant_drop)
    print("Significant F1 Score Drop:", f1_significant_drop)

    mlflow.log_metric("accuracy_significant_drop", int(accuracy_significant_drop))
    mlflow.log_metric("f1_significant_drop", int(f1_significant_drop))
    mlflow.log_metric(f"{split_name}_accuracy", accuracy_current)
    mlflow.log_metric(f"{split_name}_f1", f1_current)
    mlflow.log_metric(f"{split_name}_recall", recall_current)


    print("Run completed and all data logged to MLflow!")
# Out:
# Processing and logging reference split...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step
# predictions [[1.        ]
#  [0.9999347 ]
#  [0.9999981 ]
#  [0.9999957 ]
#  [1.        ]
#  [0.99999744]
#  [0.9997682 ]
#  [1.        ]
#  [1.        ]
#  [0.9999985 ]
#  [0.99998176]
#  [1.        ]
#  [1.        ]
#  [0.9999979 ]
#  [1.        ]
#  [1.        ]
#  [0.9999997 ]
#  [0.99999976]
#  [0.9999998 ]
#  [0.9999974 ]
#  [0.99999994]
#  [0.99999964]
#  [1.        ]
#  [0.9999996 ]
#  [0.99999964]
#  [1.        ]
#  [0.9999997 ]
#  [0.9999881 ]
#  [0.9999997 ]
#  [1.        ]
#  [1.        ]
#  [0.9999964 ]]
# Processed 32/48317 images (0.07% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# predictions [[1.        ]
#  [0.99999315]
#  [0.9999996 ]
#  [0.99972886]
#  [0.9999918 ]
#  [0.99999875]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999956 ]
#  [0.9999936 ]
#  [0.9999996 ]
#  [0.9999942 ]
#  [0.9999999 ]
#  [1.        ]
#  [0.9999997 ]
#  [0.9999988 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9994605 ]
#  [0.9999999 ]
#  [0.9999998 ]
#  [0.9999988 ]
#  [0.9999999 ]
#  [0.9999992 ]
#  [0.9999996 ]
#  [1.        ]
#  [0.9999997 ]
#  [1.        ]
#  [0.9999996 ]
#  [1.        ]]
# Processed 64/48317 images (0.13% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# predictions [[1.        ]
#  [0.9999086 ]
#  [0.99999994]
#  [0.9999993 ]
#  [0.99998754]
#  [0.9999999 ]
#  [1.        ]
#  [0.99999887]
#  [1.        ]
#  [0.99904025]
#  [0.9999983 ]
#  [0.9999996 ]
#  [0.999984  ]
#  [0.9999994 ]
#  [1.        ]
#  [0.99999976]
#  [1.        ]
#  [0.99998206]
#  [1.        ]
#  [0.999948  ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999997 ]
#  [0.9999826 ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]]
# Processed 96/48317 images (0.20% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# predictions [[1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999997 ]
#  [1.        ]
#  [0.9999998 ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99997526]
#  [0.99999285]
#  [0.99999976]
#  [1.        ]
#  [0.9999772 ]
#  [0.9999992 ]
#  [0.99999565]
#  [0.99998903]
#  [1.        ]
#  [0.99999833]
#  [0.99999976]
#  [1.        ]
#  [0.99999875]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]]
# Processed 128/48317 images (0.26% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# predictions [[1.        ]
#  [1.        ]
#  [0.9997946 ]
#  [1.        ]
#  [1.        ]
#  [0.99999326]
#  [0.99999994]
#  [1.        ]
#  [1.        ]
#  [0.9999806 ]
#  [1.        ]
#  [1.        ]
#  [0.9999866 ]
#  [1.        ]
#  [0.9999996 ]
#  [1.        ]
#  [1.        ]
#  [0.9999988 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999988 ]
#  [0.99981046]
#  [0.99999934]
#  [0.99909526]
#  [0.9999994 ]
#  [1.        ]
#  [0.99999994]
#  [0.99999696]
#  [0.9999995 ]
#  [0.9999949 ]
#  [0.9999698 ]]
# Processed 160/48317 images (0.33% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# predictions [[1.        ]
#  [0.9999904 ]
#  [1.        ]
#  [0.9999988 ]
#  [0.99999934]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [0.9999973 ]
#  [1.        ]
#  [0.99999934]
#  [1.        ]
#  [0.9999997 ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [0.9999998 ]
#  [0.9999993 ]
#  [1.        ]
#  [1.        ]
#  [0.9999954 ]
#  [0.99999815]
#  [0.9998901 ]
#  [0.999999  ]
#  [1.        ]
#  [0.99999875]
#  [1.        ]
#  [0.99999917]
#  [0.9999915 ]
#  [1.        ]
#  [0.9999985 ]
#  [0.9999999 ]]
# Processed 192/48317 images (0.40% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# predictions [[1.        ]
#  [0.9999997 ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [0.9999994 ]
#  [0.9999997 ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [0.99999934]
#  [1.        ]
#  [0.99997306]
#  [0.9999816 ]
#  [1.        ]
#  [0.99996126]
#  [0.9999999 ]
#  [0.9999997 ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [0.99998   ]
#  [0.9999986 ]
#  [0.9999999 ]
#  [1.        ]
#  [0.9999995 ]
#  [1.        ]
#  [0.99999803]
#  [1.        ]
#  [0.9999998 ]]
# Processed 224/48317 images (0.46% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# predictions [[1.        ]
#  [0.9999978 ]
#  [0.9999986 ]
#  [0.9999998 ]
#  [0.9999999 ]
#  [1.        ]
#  [0.999994  ]
#  [1.        ]
#  [0.9999982 ]
#  [0.9999981 ]
#  [1.        ]
#  [0.9999988 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999857]
#  [0.9999996 ]
#  [0.99999964]
#  [0.99999744]
#  [0.99998343]
#  [0.9999999 ]
#  [1.        ]
#  [0.9999999 ]
#  [0.9999983 ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [0.9998444 ]
#  [0.99926186]
#  [0.9999997 ]
#  [1.        ]]
# Processed 256/48317 images (0.53% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# predictions [[0.9999975 ]
#  [0.999992  ]
#  [1.        ]
#  [0.99999833]
#  [0.9999827 ]
#  [0.999997  ]
#  [0.9997224 ]
#  [0.9999998 ]
#  [1.        ]
#  [0.9999985 ]
#  [1.        ]
#  [0.9999983 ]
#  [1.        ]
#  [0.9999999 ]
#  [0.9999985 ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [0.99999994]
#  [0.999987  ]
#  [1.        ]
#  [0.99999166]
#  [0.99999976]
#  [0.9999999 ]
#  [0.99999547]
#  [0.9999996 ]
#  [0.9999991 ]
#  [0.9999981 ]
#  [0.9999881 ]
#  [1.        ]
#  [0.9999938 ]
#  [1.        ]]
# Processed 288/48317 images (0.60% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# predictions [[0.99999964]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999998 ]
#  [0.9999998 ]
#  [0.9999856 ]
#  [0.99996567]
#  [1.        ]
#  [0.99980634]
#  [1.        ]
#  [0.9999938 ]
#  [0.99999994]
#  [0.9999659 ]
#  [0.9999998 ]
#  [0.99999976]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999817 ]
#  [1.        ]
#  [1.        ]
#  [0.9999998 ]
#  [0.9999952 ]
#  [0.99997693]
#  [0.99999946]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]]
# Processed 320/48317 images (0.66% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# predictions [[1.        ]
#  [0.9999996 ]
#  [1.        ]
#  [0.9999998 ]
#  [1.        ]
#  [0.9999997 ]
#  [1.        ]
#  [0.9999575 ]
#  [1.        ]
#  [0.9999994 ]
#  [0.99977654]
#  [0.9999993 ]
#  [0.9999999 ]
#  [0.99999315]
#  [1.        ]
#  [1.        ]
#  [0.99999976]
#  [1.        ]
#  [0.99980146]
#  [1.        ]
#  [0.9999897 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999756]
#  [1.        ]
#  [0.9999997 ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]]
# Processed 352/48317 images (0.73% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# predictions [[0.99999255]
#  [1.        ]
#  [1.        ]
#  [0.99999976]
#  [1.        ]
#  [0.99999285]
#  [0.9999948 ]
#  [0.99999183]
#  [0.9999999 ]
#  [1.        ]
#  [0.9999992 ]
#  [0.9999993 ]
#  [1.        ]
#  [0.99995464]
#  [0.99996185]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [0.9999998 ]
#  [0.9999999 ]
#  [0.99999994]
#  [1.        ]
#  [1.        ]
#  [0.99999976]
#  [0.9995715 ]
#  [0.99999946]
#  [0.9999998 ]
#  [0.9999953 ]
#  [0.9999999 ]
#  [0.9999987 ]
#  [0.99988574]]
# Processed 384/48317 images (0.79% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# predictions [[1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999945 ]
#  [1.        ]
#  [0.99999994]
#  [0.9999943 ]
#  [1.        ]
#  [0.9999998 ]
#  [0.9999961 ]
#  [0.9999896 ]
#  [1.        ]
#  [0.9999995 ]
#  [1.        ]
#  [0.99999934]
#  [1.        ]
#  [1.        ]
#  [0.9999074 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999994 ]
#  [0.9999998 ]
#  [1.        ]
#  [1.        ]
#  [0.9999969 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]]
# Processed 416/48317 images (0.86% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# predictions [[0.9999566 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999607]
#  [0.999999  ]
#  [0.999974  ]
#  [0.9999945 ]
#  [1.        ]
#  [0.999942  ]
#  [0.9999998 ]
#  [1.        ]
#  [0.999971  ]
#  [1.        ]
#  [0.99999964]
#  [1.        ]
#  [0.9999999 ]
#  [0.9987474 ]
#  [0.99999994]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [1.        ]
#  [0.9999994 ]
#  [0.9999496 ]
#  [0.999985  ]
#  [0.9999997 ]
#  [1.        ]
#  [0.9999996 ]
#  [0.9998021 ]]
# Processed 448/48317 images (0.93% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# predictions [[1.        ]
#  [0.99999845]
#  [0.9999981 ]
#  [0.9999811 ]
#  [1.        ]
#  [1.        ]
#  [0.9999979 ]
#  [1.        ]
#  [1.        ]
#  [0.9999525 ]
#  [0.9999659 ]
#  [0.9999989 ]
#  [1.        ]
#  [1.        ]
#  [0.9999919 ]
#  [0.9999972 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9970127 ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999998 ]
#  [1.        ]
#  [0.9999987 ]]
# Processed 480/48317 images (0.99% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# predictions [[1.        ]
#  [0.9999992 ]
#  [1.        ]
#  [0.9999789 ]
#  [0.999986  ]
#  [1.        ]
#  [0.9999986 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [0.999985  ]
#  [0.9999997 ]
#  [0.99999565]
#  [0.9999972 ]
#  [1.        ]
#  [0.9999999 ]
#  [0.9999998 ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [0.9999995 ]
#  [0.9999986 ]
#  [0.9999681 ]
#  [0.9999989 ]]
# Processed 512/48317 images (1.06% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# predictions [[0.99999934]
#  [1.        ]
#  [0.9994265 ]
#  [0.9999998 ]
#  [1.        ]
#  [0.9999903 ]
#  [0.9997768 ]
#  [0.99999875]
#  [1.        ]
#  [0.99997574]
#  [1.        ]
#  [0.9998928 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999315]
#  [1.        ]
#  [0.9999998 ]
#  [1.        ]
#  [0.99999976]
#  [0.99999994]
#  [0.9999851 ]
#  [0.9999995 ]
#  [1.        ]
#  [0.99999833]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999833]
#  [1.        ]]
# Processed 544/48317 images (1.13% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# predictions [[0.9999994 ]
#  [1.        ]
#  [1.        ]
#  [0.9999998 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999997 ]
#  [0.9999983 ]
#  [0.9999905 ]
#  [1.        ]
#  [0.9999927 ]
#  [0.9999992 ]
#  [0.9999999 ]
#  [1.        ]
#  [0.9999995 ]
#  [1.        ]
#  [0.9999995 ]
#  [1.        ]
#  [0.9999998 ]
#  [0.9999991 ]
#  [1.        ]
#  [1.        ]
#  [0.9999996 ]
#  [1.        ]
#  [0.99999964]
#  [0.9999991 ]
#  [1.        ]
#  [1.        ]
#  [0.9999918 ]
#  [1.        ]
#  [1.        ]]
# Processed 576/48317 images (1.19% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# predictions [[0.99999803]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999997 ]
#  [0.999977  ]
#  [1.        ]
#  [0.9999995 ]
#  [0.999991  ]
#  [1.        ]
#  [0.9999998 ]
#  [1.        ]
#  [0.99999726]
#  [0.99996954]
#  [1.        ]
#  [0.99997485]
#  [1.        ]
#  [0.9999999 ]
#  [0.9999999 ]
#  [0.9999993 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999726]
#  [1.        ]
#  [1.        ]
#  [0.99999875]
#  [0.9999995 ]
#  [0.99993974]
#  [0.9938185 ]
#  [0.99999976]]
# Processed 608/48317 images (1.26% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# predictions [[1.        ]
#  [1.        ]
#  [0.9999776 ]
#  [0.9999997 ]
#  [0.999995  ]
#  [0.99998546]
#  [1.        ]
#  [0.9999992 ]
#  [0.99999946]
#  [0.9999997 ]
#  [0.9999998 ]
#  [0.99999946]
#  [0.999995  ]
#  [1.        ]
#  [0.99999905]
#  [1.        ]
#  [0.99999666]
#  [0.99999964]
#  [1.        ]
#  [0.99999976]
#  [1.        ]
#  [0.9999996 ]
#  [1.        ]
#  [1.        ]
#  [0.99993503]
#  [0.9999969 ]
#  [1.        ]
#  [0.9999982 ]
#  [0.99999535]
#  [0.99998105]
#  [1.        ]
#  [1.        ]]
# Processed 640/48317 images (1.32% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# predictions [[0.997829  ]
#  [0.9999574 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [0.9999982 ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [0.9995058 ]
#  [0.99999917]
#  [1.        ]
#  [0.9999912 ]
#  [0.9999964 ]
#  [0.9999347 ]
#  [1.        ]
#  [1.        ]
#  [0.9999973 ]
#  [0.9999996 ]
#  [1.        ]
#  [1.        ]
#  [0.99998724]
#  [1.        ]
#  [1.        ]]
# Processed 672/48317 images (1.39% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# predictions [[1.        ]
#  [0.99999994]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [0.99999267]
#  [1.        ]
#  [0.9999993 ]
#  [0.99999154]
#  [0.9999854 ]
#  [1.        ]
#  [0.9999994 ]
#  [0.9999996 ]
#  [0.9999821 ]
#  [0.99999964]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999996 ]
#  [0.9999998 ]
#  [0.9999998 ]
#  [1.        ]
#  [0.99999857]
#  [0.9999992 ]
#  [1.        ]
#  [0.9999987 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999976]]
# Processed 704/48317 images (1.46% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# predictions [[1.        ]
#  [0.9999971 ]
#  [1.        ]
#  [0.9999999 ]
#  [0.9999997 ]
#  [1.        ]
#  [0.999999  ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [0.9999992 ]
#  [0.99999994]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.999999  ]
#  [0.99999994]
#  [1.        ]
#  [0.99999976]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999991 ]
#  [0.99999714]
#  [1.        ]
#  [0.9999986 ]
#  [0.99999976]
#  [0.9999758 ]
#  [0.99999994]]
# Processed 736/48317 images (1.52% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# predictions [[0.99997526]
#  [1.        ]
#  [0.9999996 ]
#  [0.99999976]
#  [1.        ]
#  [0.9999596 ]
#  [1.        ]
#  [0.99999994]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [0.9999863 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999744]
#  [0.99999833]
#  [1.        ]
#  [0.99995905]
#  [0.9996923 ]
#  [0.9999982 ]
#  [0.9999992 ]
#  [0.9999954 ]
#  [0.9999993 ]
#  [0.9999955 ]]
# Processed 768/48317 images (1.59% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# predictions [[1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999997 ]
#  [1.        ]
#  [0.99965024]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999774 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999998 ]
#  [0.9999999 ]
#  [0.9999999 ]
#  [0.99994004]
#  [0.9999237 ]
#  [0.9999997 ]
#  [0.9999982 ]
#  [0.99998957]
#  [0.9999949 ]
#  [0.9999893 ]
#  [1.        ]
#  [0.9999712 ]
#  [1.        ]
#  [1.        ]
#  [0.99999917]
#  [1.        ]
#  [0.9999998 ]
#  [0.99999857]
#  [1.        ]]
# Processed 800/48317 images (1.66% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# predictions [[0.99999976]
#  [0.9999999 ]
#  [1.        ]
#  [0.9999989 ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [0.99998677]
#  [1.        ]
#  [0.99999946]
#  [1.        ]
#  [0.99999875]
#  [1.        ]
#  [0.99999917]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [0.9999612 ]
#  [0.99997604]
#  [0.9999984 ]
#  [0.9999874 ]
#  [0.99999964]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]]
# Processed 832/48317 images (1.72% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# predictions [[1.        ]
#  [1.        ]
#  [0.9999982 ]
#  [1.        ]
#  [0.9999984 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999988 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999997 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999853 ]
#  [1.        ]
#  [0.99999785]
#  [0.9999969 ]
#  [1.        ]
#  [1.        ]
#  [0.99999976]
#  [0.9999171 ]
#  [0.99999976]
#  [1.        ]
#  [1.        ]
#  [0.99999714]
#  [1.        ]
#  [0.99995655]
#  [1.        ]]
# Processed 864/48317 images (1.79% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# predictions [[0.9999989 ]
#  [0.99997115]
#  [1.        ]
#  [0.9749503 ]
#  [0.9996981 ]
#  [1.        ]
#  [0.9999889 ]
#  [1.        ]
#  [0.99999946]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [0.9999993 ]
#  [1.        ]
#  [1.        ]
#  [0.9999994 ]
#  [0.9999995 ]
#  [1.        ]
#  [0.9999995 ]
#  [0.99999946]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999976]
#  [0.99999845]
#  [0.99998885]
#  [0.99997246]]
# Processed 896/48317 images (1.85% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# predictions [[0.9999856 ]
#  [1.        ]
#  [1.        ]
#  [0.99999535]
#  [0.9999938 ]
#  [1.        ]
#  [1.        ]
#  [0.99995524]
#  [0.99999416]
#  [0.9999982 ]
#  [1.        ]
#  [1.        ]
#  [0.99999934]
#  [1.        ]
#  [0.9999467 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999997 ]
#  [0.9999996 ]
#  [1.        ]
#  [0.99999976]
#  [0.9999997 ]
#  [0.9999865 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999976]
#  [0.9999996 ]]
# Processed 928/48317 images (1.92% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# predictions [[0.99999976]
#  [0.9999209 ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [0.99999887]
#  [0.99999917]
#  [1.        ]
#  [0.9999997 ]
#  [1.        ]
#  [0.999963  ]
#  [1.        ]
#  [1.        ]
#  [0.9999996 ]
#  [0.99999774]
#  [0.99999994]
#  [1.        ]
#  [1.        ]
#  [0.9999998 ]
#  [1.        ]
#  [1.        ]
#  [0.9999995 ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999998 ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [0.9999998 ]]
# Processed 960/48317 images (1.99% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# predictions [[1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999976]
#  [1.        ]
#  [0.9999998 ]
#  [0.99995154]
#  [0.99986273]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999507 ]
#  [0.9999999 ]
#  [0.9999939 ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [0.99999917]
#  [0.9999981 ]
#  [1.        ]
#  [0.99999905]
#  [1.        ]
#  [0.9999998 ]
#  [1.        ]
#  [0.9999969 ]
#  [1.        ]
#  [1.        ]
#  [0.9999847 ]]
# Processed 992/48317 images (2.05% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# predictions [[1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999877 ]
#  [0.99973994]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999909 ]
#  [0.99999934]
#  [0.99996835]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999986 ]
#  [0.9999998 ]
#  [1.        ]
#  [0.99995667]
#  [0.99980044]
#  [1.        ]
#  [1.        ]
#  [0.999992  ]
#  [1.        ]
#  [0.99999994]
#  [0.999996  ]
#  [1.        ]]
# Processed 1024/48317 images (2.12% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# predictions [[0.9999994 ]
#  [0.9999999 ]
#  [0.9992504 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [0.99999815]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [0.9999959 ]
#  [0.99999934]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999997 ]
#  [0.99998146]
#  [0.99999994]
#  [1.        ]
#  [0.99999905]
#  [1.        ]
#  [0.9999994 ]
#  [1.        ]
#  [0.9990742 ]
#  [0.99999994]
#  [0.9990121 ]]
# Processed 1056/48317 images (2.19% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# predictions [[0.9999997 ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [0.9999984 ]
#  [0.9999999 ]
#  [0.99999505]
#  [1.        ]
#  [1.        ]
#  [0.9999998 ]
#  [0.99999976]
#  [1.        ]
#  [0.9999903 ]
#  [1.        ]
#  [0.99996203]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999996 ]
#  [0.9999994 ]
#  [0.9999697 ]
#  [0.9999992 ]
#  [0.9999932 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999657 ]
#  [0.999989  ]
#  [0.9999964 ]]
# Processed 1088/48317 images (2.25% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# predictions [[0.9999991 ]
#  [1.        ]
#  [0.99999815]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999684]
#  [1.        ]
#  [0.99999803]
#  [1.        ]
#  [0.9999843 ]
#  [1.        ]
#  [0.9999986 ]
#  [0.9999984 ]
#  [1.        ]
#  [1.        ]
#  [0.99999714]
#  [0.99999946]
#  [1.        ]
#  [0.9999998 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [0.9999878 ]
#  [0.99999994]
#  [0.9999998 ]
#  [0.99999905]
#  [0.99999964]]
# Processed 1120/48317 images (2.32% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# predictions [[1.        ]
#  [1.        ]
#  [0.99970764]
#  [1.        ]
#  [0.9999999 ]
#  [0.9999998 ]
#  [1.        ]
#  [1.        ]
#  [0.99996084]
#  [0.9999999 ]
#  [0.9999999 ]
#  [0.99999785]
#  [1.        ]
#  [0.9999995 ]
#  [0.9999964 ]
#  [1.        ]
#  [0.9999938 ]
#  [0.9999706 ]
#  [1.        ]
#  [0.99992645]
#  [0.9999997 ]
#  [1.        ]
#  [0.99999964]
#  [0.99999976]
#  [1.        ]
#  [0.99999976]
#  [1.        ]
#  [1.        ]
#  [0.9999958 ]
#  [0.999999  ]
#  [1.        ]
#  [1.        ]]
# Processed 1152/48317 images (2.38% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# predictions [[0.99999994]
#  [0.999766  ]
#  [0.99997276]
#  [0.99999785]
#  [0.9999992 ]
#  [0.9999998 ]
#  [1.        ]
#  [1.        ]
#  [0.9999995 ]
#  [0.9999998 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999946 ]
#  [0.99999994]
#  [0.9999999 ]
#  [0.9999997 ]
#  [0.99999994]
#  [1.        ]
#  [0.99999994]
#  [0.99999815]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [0.9999987 ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]]
# Processed 1184/48317 images (2.45% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# predictions [[1.        ]
#  [0.99958616]
#  [0.99999744]
#  [1.        ]
#  [0.99999976]
#  [0.9999997 ]
#  [1.        ]
#  [1.        ]
#  [0.9999995 ]
#  [0.9991843 ]
#  [1.        ]
#  [1.        ]
#  [0.9999998 ]
#  [1.        ]
#  [0.9999999 ]
#  [0.9999999 ]
#  [0.9995692 ]
#  [0.9999994 ]
#  [1.        ]
#  [0.9999999 ]
#  [0.9999995 ]
#  [0.9999999 ]
#  [0.9999978 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]]
# Processed 1216/48317 images (2.52% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# predictions [[1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999992 ]
#  [0.99999774]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [0.999997  ]
#  [1.        ]
#  [0.9999999 ]
#  [0.9999996 ]
#  [0.99999934]
#  [1.        ]
#  [0.99999964]
#  [1.        ]
#  [1.        ]
#  [0.99999976]
#  [1.        ]
#  [0.9999992 ]
#  [0.99999946]
#  [1.        ]
#  [1.        ]
#  [0.9999998 ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [0.9996988 ]
#  [0.9999999 ]
#  [0.9986494 ]]
# Processed 1248/48317 images (2.58% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# predictions [[1.        ]
#  [0.99999994]
#  [0.9999999 ]
#  [0.99999976]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [0.9994144 ]
#  [1.        ]
#  [0.99999064]
#  [1.        ]
#  [1.        ]
#  [0.99999756]
#  [0.999998  ]
#  [0.9999992 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999976]
#  [0.99999636]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [0.99962664]
#  [1.        ]]
# Processed 1280/48317 images (2.65% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# predictions [[0.9999999 ]
#  [0.9999997 ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [0.99999976]
#  [0.99999976]
#  [1.        ]
#  [1.        ]
#  [0.9999987 ]
#  [0.9999902 ]
#  [0.99738085]
#  [1.        ]
#  [0.9999999 ]
#  [0.9999999 ]
#  [0.9999999 ]
#  [0.9999994 ]
#  [0.9999943 ]
#  [1.        ]
#  [0.99999344]
#  [1.        ]
#  [0.9999998 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999976]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]]
# Processed 1312/48317 images (2.72% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# predictions [[0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [0.9979388 ]
#  [0.9999991 ]
#  [1.        ]
#  [1.        ]
#  [0.9999998 ]
#  [1.        ]
#  [0.9998242 ]
#  [0.9999999 ]
#  [1.        ]
#  [0.9999987 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999977 ]
#  [0.9999354 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [0.9999999 ]
#  [1.        ]
#  [0.99998415]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]]
# Processed 1344/48317 images (2.78% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# predictions [[0.99999994]
#  [0.99967235]
#  [0.99999934]
#  [0.9999545 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9994086 ]
#  [1.        ]
#  [0.9999999 ]
#  [0.999998  ]
#  [1.        ]
#  [0.99999976]
#  [0.99996585]
#  [1.        ]
#  [1.        ]
#  [0.99999666]
#  [1.        ]
#  [0.99999994]
#  [0.99999994]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [0.999999  ]
#  [0.9999983 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]]
# Processed 1376/48317 images (2.85% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# predictions [[1.        ]
#  [0.99991834]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999964]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999195]
#  [0.99999994]
#  [0.999912  ]
#  [0.99999994]
#  [1.        ]
#  [0.99999666]
#  [1.        ]
#  [1.        ]
#  [0.9985042 ]
#  [1.        ]
#  [0.99997056]
#  [1.        ]
#  [0.99999976]
#  [0.9998088 ]
#  [0.99999577]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999986 ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]]
# Processed 1408/48317 images (2.91% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# predictions [[1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9819201 ]
#  [1.        ]
#  [0.9999997 ]
#  [0.9999998 ]
#  [1.        ]
#  [0.99999964]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999996 ]
#  [0.9999993 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99997824]
#  [0.99999875]
#  [1.        ]
#  [0.99815285]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]]
# Processed 1440/48317 images (2.98% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# predictions [[1.        ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [0.9999999 ]
#  [1.        ]
#  [0.9998982 ]
#  [0.9999999 ]
#  [1.        ]
#  [0.99999756]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [0.99999994]
#  [1.        ]
#  [0.9999994 ]
#  [0.99924916]
#  [1.        ]
#  [1.        ]
#  [0.9999996 ]
#  [0.99999994]
#  [1.        ]
#  [1.        ]
#  [0.99999875]
#  [0.9999986 ]
#  [1.        ]
#  [0.9999957 ]
#  [1.        ]
#  [1.        ]]
# Processed 1472/48317 images (3.05% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# predictions [[0.99999934]
#  [0.99999994]
#  [1.        ]
#  [1.        ]
#  [0.99999964]
#  [1.        ]
#  [0.9999297 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99995166]
#  [1.        ]
#  [0.9999983 ]
#  [0.99999833]
#  [0.99999946]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.0071448 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999996 ]
#  [1.        ]
#  [1.        ]
#  [0.9999912 ]
#  [1.        ]]
# Processed 1504/48317 images (3.11% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# predictions [[1.        ]
#  [1.        ]
#  [0.9999985 ]
#  [1.        ]
#  [0.99999976]
#  [1.        ]
#  [0.9999993 ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999998 ]
#  [0.9999826 ]
#  [1.        ]
#  [0.99999994]
#  [0.9999997 ]
#  [0.99997795]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [1.        ]
#  [0.99999774]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999964]
#  [1.        ]
#  [0.9999979 ]
#  [0.99999964]]
# Processed 1536/48317 images (3.18% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# predictions [[0.9999998 ]
#  [0.9999998 ]
#  [1.        ]
#  [0.99999976]
#  [1.        ]
#  [1.        ]
#  [0.999998  ]
#  [1.        ]
#  [1.        ]
#  [0.9999998 ]
#  [0.9999948 ]
#  [0.99999744]
#  [1.        ]
#  [1.        ]
#  [0.9809211 ]
#  [1.        ]
#  [1.        ]
#  [0.99999905]
#  [1.        ]
#  [1.        ]
#  [0.99999094]
#  [0.9999998 ]
#  [0.9999998 ]
#  [0.99999565]
#  [0.9999998 ]
#  [0.9990954 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [0.99999994]
#  [0.9999994 ]]
# Processed 1568/48317 images (3.25% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# predictions [[0.9999999 ]
#  [0.9999996 ]
#  [0.9999986 ]
#  [1.        ]
#  [1.        ]
#  [0.9999971 ]
#  [1.        ]
#  [0.9999998 ]
#  [0.9999999 ]
#  [0.9999992 ]
#  [0.99978626]
#  [0.99998844]
#  [1.        ]
#  [1.        ]
#  [0.9999998 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999905]
#  [1.        ]
#  [1.        ]
#  [0.9998833 ]
#  [0.9994352 ]
#  [1.        ]
#  [0.99998933]
#  [0.9996644 ]
#  [0.9999999 ]
#  [0.9994012 ]
#  [1.        ]
#  [0.9999997 ]
#  [0.99999905]
#  [0.99999994]]
# Processed 1600/48317 images (3.31% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# predictions [[1.        ]
#  [0.99999976]
#  [1.        ]
#  [0.9999998 ]
#  [0.99996215]
#  [1.        ]
#  [0.999991  ]
#  [0.99998736]
#  [0.9999999 ]
#  [1.        ]
#  [0.99999976]
#  [0.9999675 ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [0.99999994]
#  [0.9999822 ]
#  [1.        ]
#  [0.9999998 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999997 ]
#  [0.99999976]
#  [1.        ]
#  [1.        ]
#  [0.99999636]
#  [1.        ]
#  [1.        ]]
# Processed 1632/48317 images (3.38% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# predictions [[1.        ]
#  [0.9999999 ]
#  [0.99999964]
#  [0.99994165]
#  [0.99999994]
#  [1.        ]
#  [1.        ]
#  [0.9999929 ]
#  [0.9999983 ]
#  [0.9999998 ]
#  [0.9999999 ]
#  [0.99999976]
#  [1.        ]
#  [1.        ]
#  [0.99999917]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999607]
#  [0.9999995 ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [0.99999607]
#  [1.        ]
#  [0.9999989 ]
#  [0.9999999 ]]
# Processed 1664/48317 images (3.44% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# predictions [[1.        ]
#  [1.        ]
#  [0.99999905]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [0.9999982 ]
#  [0.983985  ]
#  [1.        ]
#  [1.        ]
#  [0.998989  ]
#  [1.        ]
#  [1.        ]
#  [0.99833894]
#  [1.        ]
#  [0.9999868 ]
#  [0.9987602 ]
#  [1.        ]
#  [0.9999999 ]
#  [0.99995995]
#  [0.9999994 ]
#  [0.9995406 ]
#  [1.        ]
#  [0.9999999 ]
#  [0.9999999 ]
#  [0.9979973 ]
#  [1.        ]
#  [0.9841792 ]
#  [0.9999995 ]
#  [0.999999  ]
#  [0.9999999 ]
#  [1.        ]]
# Processed 1696/48317 images (3.51% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# predictions [[1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [0.9999809 ]
#  [1.        ]
#  [0.9997846 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999964]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999932 ]
#  [0.99999994]
#  [0.99944276]
#  [1.        ]
#  [1.        ]
#  [0.99999976]
#  [0.99925286]
#  [0.99999994]
#  [0.9999998 ]
#  [1.        ]
#  [0.99880147]
#  [1.        ]
#  [1.        ]
#  [0.99988794]
#  [1.        ]
#  [1.        ]]
# Processed 1728/48317 images (3.58% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# predictions [[1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999857]
#  [0.99999964]
#  [1.        ]
#  [0.99997765]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99868476]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999998 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [0.9999999 ]
#  [0.99999994]
#  [1.        ]
#  [1.        ]
#  [1.        ]]
# Processed 1760/48317 images (3.64% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# predictions [[0.9999998 ]
#  [0.9999681 ]
#  [0.99976414]
#  [1.        ]
#  [0.99994516]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [0.9999999 ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [0.99999994]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999714]
#  [1.        ]]
# Processed 1792/48317 images (3.71% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# predictions [[0.99999946]
#  [1.        ]
#  [1.        ]
#  [0.99999946]
#  [0.99954903]
#  [0.9999981 ]
#  [1.        ]
#  [0.99999887]
#  [1.        ]
#  [0.99999905]
#  [1.        ]
#  [0.99999803]
#  [0.99999964]
#  [0.99999964]
#  [0.99999785]
#  [0.9999572 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999934]
#  [0.999973  ]
#  [0.9997353 ]
#  [0.9999831 ]
#  [1.        ]
#  [0.99999976]
#  [0.9999971 ]
#  [0.9999994 ]
#  [0.9997515 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]]
# Processed 1824/48317 images (3.78% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# predictions [[1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999565]
#  [0.9999982 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99953145]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99997544]
#  [1.        ]
#  [0.9999996 ]
#  [1.        ]
#  [0.99999946]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [0.93801105]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [0.9999998 ]]
# Processed 1856/48317 images (3.84% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# predictions [[0.999711  ]
#  [0.9999998 ]
#  [1.        ]
#  [0.9999995 ]
#  [0.9999999 ]
#  [0.99999994]
#  [0.99999833]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999997 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [1.        ]
#  [0.99995404]
#  [1.        ]
#  [0.9999996 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]]
# Processed 1888/48317 images (3.91% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# predictions [[1.        ]
#  [1.        ]
#  [0.99984336]
#  [0.99999994]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [0.99999815]
#  [1.        ]
#  [0.99989295]
#  [0.99997306]
#  [0.9999998 ]
#  [0.99999994]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [0.9999999 ]
#  [0.99999446]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [0.9999978 ]
#  [0.99999994]
#  [0.9939095 ]
#  [1.        ]
#  [0.9999998 ]
#  [0.99999774]]
# Processed 1920/48317 images (3.97% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# predictions [[1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [0.9999998 ]
#  [0.99998206]
#  [1.        ]
#  [0.9999996 ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [0.999997  ]
#  [0.99999946]
#  [0.9999997 ]
#  [1.        ]
#  [0.99999994]
#  [0.99999976]
#  [0.99961275]
#  [1.        ]
#  [0.9999999 ]
#  [0.01725241]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999985 ]
#  [1.        ]
#  [0.999983  ]
#  [0.9999999 ]]
# Processed 1952/48317 images (4.04% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# predictions [[1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999464]
#  [0.9998497 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999998 ]
#  [0.99999976]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99996483]
#  [1.        ]
#  [0.9989715 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999106]
#  [0.9999998 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999994 ]
#  [1.        ]
#  [0.99999976]]
# Processed 1984/48317 images (4.11% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# predictions [[1.        ]
#  [0.99999523]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9996259 ]
#  [0.99998057]
#  [0.9999865 ]
#  [0.99999845]
#  [0.9999943 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999987 ]
#  [1.        ]
#  [1.        ]
#  [0.99999946]
#  [1.        ]
#  [0.99999744]
#  [1.        ]
#  [1.        ]
#  [0.99999136]
#  [0.9999984 ]
#  [0.99999964]
#  [1.        ]
#  [1.        ]
#  [0.9999998 ]
#  [0.99999994]
#  [1.        ]
#  [0.9999998 ]
#  [1.        ]]
# Processed 2016/48317 images (4.17% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# predictions [[1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [0.9999998 ]
#  [0.99999994]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999887]
#  [1.        ]
#  [1.        ]
#  [0.9999769 ]
#  [0.99999994]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [0.99999875]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]]
# Processed 2048/48317 images (4.24% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# predictions [[1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999921 ]
#  [1.        ]
#  [0.99999994]
#  [0.9999985 ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999938 ]
#  [0.9999991 ]
#  [1.        ]
#  [0.999933  ]
#  [0.9999997 ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.6825717 ]
#  [1.        ]
#  [0.9999995 ]]
# Processed 2080/48317 images (4.30% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# predictions [[0.9999999 ]
#  [0.9999997 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99998945]
#  [1.        ]
#  [1.        ]
#  [0.99885106]
#  [1.        ]
#  [1.        ]
#  [0.9999971 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999875]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9998135 ]
#  [0.9999999 ]
#  [0.9999749 ]
#  [1.        ]]
# Processed 2112/48317 images (4.37% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# predictions [[0.9999999 ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9935223 ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999987 ]
#  [0.99999964]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [0.9999998 ]
#  [0.9999506 ]
#  [1.        ]
#  [0.99999976]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999995 ]]
# Processed 2144/48317 images (4.44% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# predictions [[1.        ]
#  [0.9998825 ]
#  [1.        ]
#  [0.9999887 ]
#  [0.9999889 ]
#  [1.        ]
#  [1.        ]
#  [0.89612085]
#  [0.99999684]
#  [1.        ]
#  [1.        ]
#  [0.99999666]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [0.9989586 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999997 ]
#  [0.02923003]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [0.99956006]
#  [0.99999964]
#  [0.9999846 ]
#  [1.        ]
#  [0.9999531 ]
#  [1.        ]]
# Processed 2176/48317 images (4.50% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# predictions [[1.        ]
#  [0.99900806]
#  [0.9987289 ]
#  [0.9999999 ]
#  [0.9999999 ]
#  [0.9999992 ]
#  [1.        ]
#  [0.9999997 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [1.        ]
#  [0.9996509 ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999998 ]
#  [0.99999964]
#  [1.        ]
#  [1.        ]]
# Processed 2208/48317 images (4.57% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# predictions [[1.        ]
#  [1.        ]
#  [0.99999636]
#  [1.        ]
#  [0.99997365]
#  [0.99999994]
#  [0.99997747]
#  [0.9974592 ]
#  [1.        ]
#  [0.99999994]
#  [0.9996468 ]
#  [1.        ]
#  [0.99999547]
#  [0.9999805 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999998 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999845]
#  [1.        ]
#  [1.        ]
#  [1.        ]]
# Processed 2240/48317 images (4.64% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# predictions [[0.9999997 ]
#  [1.        ]
#  [1.        ]
#  [0.9998966 ]
#  [0.9999916 ]
#  [0.99993694]
#  [0.9999991 ]
#  [0.9999999 ]
#  [1.        ]
#  [0.9999294 ]
#  [1.        ]
#  [1.        ]
#  [0.9999962 ]
#  [0.99998385]
#  [1.        ]
#  [0.9999998 ]
#  [1.        ]
#  [1.        ]
#  [0.98618525]
#  [1.        ]
#  [0.9995059 ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [0.99999785]
#  [1.        ]
#  [0.9893241 ]
#  [0.9999594 ]
#  [0.9999998 ]
#  [0.99999905]
#  [0.99999523]]
# Processed 2272/48317 images (4.70% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# predictions [[0.9999998 ]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [0.9996027 ]
#  [1.        ]
#  [0.9999937 ]
#  [0.99999267]
#  [0.9999966 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999998 ]
#  [1.        ]
#  [1.        ]
#  [0.99999976]
#  [1.        ]
#  [0.99999905]
#  [0.99980444]
#  [0.9999994 ]
#  [0.9999877 ]
#  [0.99999887]
#  [0.9999123 ]
#  [0.9999998 ]
#  [1.        ]
#  [0.9480182 ]
#  [0.9999962 ]
#  [0.9999984 ]
#  [0.9999248 ]
#  [1.        ]
#  [0.9999978 ]
#  [0.9999994 ]]
# Processed 2304/48317 images (4.77% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# predictions [[1.        ]
#  [0.99997574]
#  [0.9999982 ]
#  [0.99999684]
#  [0.99999297]
#  [1.        ]
#  [0.9999995 ]
#  [0.99999595]
#  [0.9999996 ]
#  [0.9999997 ]
#  [0.99999964]
#  [0.9999996 ]
#  [0.99842864]
#  [0.9999998 ]
#  [0.99999446]
#  [1.        ]
#  [0.9999999 ]
#  [1.        ]
#  [0.99999994]
#  [0.99971664]
#  [1.        ]
#  [0.9968038 ]
#  [0.99999887]
#  [0.9999967 ]
#  [1.        ]
#  [0.9999749 ]
#  [1.        ]
#  [0.99999976]
#  [1.        ]
#  [0.9998388 ]
#  [0.99999976]
#  [0.99999994]]
# Processed 2336/48317 images (4.83% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# predictions [[1.        ]
#  [0.99494696]
#  [0.9999905 ]
#  [0.9999144 ]
#  [1.        ]
#  [0.9999997 ]
#  [0.99969584]
#  [0.9999979 ]
#  [0.99999136]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [0.9915629 ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [0.9999998 ]
#  [1.        ]
#  [0.9999999 ]
#  [0.99999964]
#  [0.9999999 ]
#  [1.        ]
#  [0.99999946]
#  [0.9999867 ]
#  [0.9999942 ]
#  [0.99999976]
#  [0.99998647]
#  [1.        ]
#  [1.        ]
#  [0.99999917]
#  [0.9998264 ]
#  [0.99998283]]
# Processed 2368/48317 images (4.90% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# predictions [[1.        ]
#  [1.        ]
#  [0.99771816]
#  [0.99998194]
#  [0.9997733 ]
#  [0.99590945]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99930674]
#  [0.999926  ]
#  [0.9999931 ]
#  [1.        ]
#  [0.9999995 ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [0.9999098 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99996173]
#  [1.        ]
#  [1.        ]
#  [0.9999899 ]
#  [0.99928015]
#  [0.9999849 ]
#  [0.9999996 ]
#  [0.9999973 ]
#  [0.9999994 ]
#  [0.99998474]]
# Processed 2400/48317 images (4.97% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# predictions [[1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [0.99962014]
#  [0.99999976]
#  [0.9999997 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999654]
#  [0.9999988 ]
#  [0.9999981 ]
#  [0.99999994]
#  [0.99997926]
#  [0.9999681 ]
#  [0.9999995 ]
#  [1.        ]
#  [0.9999999 ]
#  [0.9999995 ]
#  [0.9999956 ]
#  [1.        ]
#  [0.9999999 ]
#  [0.9999976 ]
#  [0.99985963]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999946]
#  [0.9999851 ]
#  [0.99996316]
#  [1.        ]
#  [1.        ]]
# Processed 2432/48317 images (5.03% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# predictions [[0.99999994]
#  [1.        ]
#  [0.9999994 ]
#  [0.9997574 ]
#  [1.        ]
#  [0.9999881 ]
#  [0.9999965 ]
#  [0.99999785]
#  [0.9999999 ]
#  [0.99994504]
#  [0.99999917]
#  [0.9999999 ]
#  [0.9999835 ]
#  [1.        ]
#  [0.9999995 ]
#  [0.99998355]
#  [0.9999965 ]
#  [0.9984141 ]
#  [1.        ]
#  [1.        ]
#  [0.9999805 ]
#  [0.9999999 ]
#  [1.        ]
#  [0.99999934]
#  [1.        ]
#  [0.99992627]
#  [0.9999998 ]
#  [0.99999946]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]]
# Processed 2464/48317 images (5.10% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# predictions [[1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999581 ]
#  [1.        ]
#  [0.9999998 ]
#  [1.        ]
#  [0.99985504]
#  [1.        ]
#  [0.99999887]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999998 ]
#  [0.99999875]
#  [0.9999978 ]
#  [0.99996924]
#  [1.        ]
#  [0.99998105]
#  [0.9999974 ]
#  [1.        ]
#  [0.99998903]
#  [0.99999434]
#  [0.99997354]
#  [1.        ]
#  [0.9999772 ]
#  [0.99999887]
#  [0.9999945 ]
#  [0.99999976]
#  [1.        ]
#  [0.99999934]
#  [1.        ]]
# Processed 2496/48317 images (5.17% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# predictions [[0.99999595]
#  [0.99999964]
#  [1.        ]
#  [0.99999994]
#  [0.99997693]
#  [0.99999964]
#  [1.        ]
#  [1.        ]
#  [0.99999636]
#  [0.98859364]
#  [0.9999999 ]
#  [0.99999714]
#  [0.99999547]
#  [0.99999136]
#  [1.        ]
#  [0.9999998 ]
#  [0.9999877 ]
#  [0.99986655]
#  [0.99999946]
#  [0.99999857]
#  [1.        ]
#  [0.9983475 ]
#  [0.99999964]
#  [0.9999148 ]
#  [1.        ]
#  [0.9999982 ]
#  [0.99999976]
#  [1.        ]
#  [0.99999464]
#  [0.9999927 ]
#  [0.9999341 ]
#  [1.        ]]
# Processed 2528/48317 images (5.23% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# predictions [[1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999993 ]
#  [0.9999997 ]
#  [0.99917066]
#  [0.9999851 ]
#  [1.        ]
#  [0.9999997 ]
#  [0.9947009 ]
#  [1.        ]
#  [0.999997  ]
#  [0.99994016]
#  [0.9999983 ]
#  [0.99999964]
#  [0.99999976]
#  [1.        ]
#  [0.99999857]
#  [0.99998635]
#  [1.        ]
#  [0.99994755]
#  [0.9608086 ]
#  [1.        ]
#  [1.        ]
#  [0.9940996 ]
#  [0.9984548 ]
#  [0.9999998 ]
#  [0.9999998 ]
#  [1.        ]
#  [0.99999654]]
# Processed 2560/48317 images (5.30% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# predictions [[1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.999999  ]
#  [1.        ]
#  [0.9999387 ]
#  [1.        ]
#  [0.98982984]
#  [0.9999998 ]
#  [1.        ]
#  [0.9994816 ]
#  [0.9999102 ]
#  [0.9999998 ]
#  [1.        ]
#  [0.99999946]
#  [0.9999998 ]
#  [0.99999124]
#  [0.9999988 ]
#  [0.99999034]
#  [0.9999858 ]
#  [1.        ]
#  [1.        ]
#  [0.99951273]
#  [0.99999905]
#  [0.99999714]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999949 ]
#  [1.        ]
#  [0.9997713 ]]
# Processed 2592/48317 images (5.36% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# predictions [[1.        ]
#  [0.9999682 ]
#  [0.9999996 ]
#  [0.9989809 ]
#  [0.99999845]
#  [0.9871973 ]
#  [0.99999964]
#  [1.        ]
#  [0.98052686]
#  [0.9999366 ]
#  [1.        ]
#  [0.9999994 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999969 ]
#  [1.        ]
#  [0.99997103]
#  [0.99999774]
#  [0.99911386]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999976]
#  [1.        ]
#  [1.        ]
#  [0.99924654]
#  [1.        ]
#  [0.999881  ]
#  [0.9999994 ]
#  [0.99999815]
#  [1.        ]]
# Processed 2624/48317 images (5.43% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# predictions [[0.99999416]
#  [1.        ]
#  [0.9999872 ]
#  [1.        ]
#  [0.99998045]
#  [0.9999974 ]
#  [0.9997126 ]
#  [0.99959254]
#  [0.9999995 ]
#  [0.9944963 ]
#  [0.9999978 ]
#  [0.9999998 ]
#  [1.        ]
#  [0.9998951 ]
#  [0.99916065]
#  [0.9999999 ]
#  [1.        ]
#  [0.99999934]
#  [1.        ]
#  [0.99999917]
#  [0.9993691 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999976]
#  [1.        ]
#  [1.        ]
#  [0.9999997 ]
#  [1.        ]]
# Processed 2656/48317 images (5.50% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# predictions [[1.        ]
#  [1.        ]
#  [0.99997187]
#  [0.99999845]
#  [0.99999774]
#  [0.99997395]
#  [0.9999997 ]
#  [0.99983793]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999637 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999213]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999635 ]
#  [1.        ]
#  [0.99984956]
#  [0.99999416]
#  [1.        ]
#  [1.        ]
#  [0.99999535]
#  [0.9990478 ]
#  [0.9999963 ]
#  [0.99999976]]
# Processed 2688/48317 images (5.56% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# predictions [[0.99999297]
#  [0.9999997 ]
#  [0.9999939 ]
#  [1.        ]
#  [1.        ]
#  [0.9999999 ]
#  [0.9999489 ]
#  [0.9999986 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [0.99988526]
#  [1.        ]
#  [0.99999326]
#  [0.9849729 ]
#  [0.9982975 ]
#  [0.999983  ]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [0.9997326 ]
#  [1.        ]
#  [1.        ]
#  [0.99999845]
#  [0.99999917]
#  [1.        ]
#  [0.9999999 ]
#  [0.9999953 ]]
# Processed 2720/48317 images (5.63% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# predictions [[0.9999998 ]
#  [0.9999788 ]
#  [0.9999997 ]
#  [0.9999999 ]
#  [0.99999446]
#  [0.999998  ]
#  [1.        ]
#  [0.99999434]
#  [0.99998647]
#  [1.        ]
#  [1.        ]
#  [0.99999994]
#  [0.99999994]
#  [0.99999976]
#  [0.9997707 ]
#  [0.9999964 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999905]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99983513]
#  [0.9976737 ]
#  [0.99788314]
#  [0.99999654]
#  [0.9999937 ]
#  [0.9982831 ]
#  [1.        ]
#  [1.        ]]
# Processed 2752/48317 images (5.70% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# predictions [[0.99999994]
#  [1.        ]
#  [0.9999953 ]
#  [0.99467635]
#  [0.9999955 ]
#  [0.9999994 ]
#  [0.9985762 ]
#  [0.99975824]
#  [0.99999696]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9999992 ]
#  [1.        ]
#  [0.99999803]
#  [1.        ]
#  [1.        ]
#  [0.99999934]
#  [0.99999976]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999154]
#  [0.991784  ]
#  [0.9999962 ]
#  [1.        ]
#  [0.99999595]
#  [1.        ]
#  [0.9999933 ]
#  [1.        ]
#  [0.99629325]
#  [1.        ]]
# Processed 2784/48317 images (5.76% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# predictions [[1.        ]
#  [1.        ]
#  [0.99999917]
#  [1.        ]
#  [0.99999934]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999297]
#  [0.99997336]
#  [0.99999994]
#  [1.        ]
#  [0.99999994]
#  [1.        ]
#  [0.99999756]
#  [1.        ]
#  [1.        ]
#  [0.9997474 ]
#  [0.9999981 ]
#  [0.999999  ]
#  [0.9999988 ]
#  [0.999     ]
#  [0.99999875]
#  [0.99999857]
#  [0.99999994]
#  [0.9999993 ]
#  [1.        ]
#  [0.9999999 ]
#  [0.9999964 ]
#  [0.999977  ]
#  [0.9999987 ]
#  [1.        ]]
# Processed 2816/48317 images (5.83% complete)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# predictions [[1.        ]
#  [0.99999535]
#  [0.99998176]
#  [1.        ]
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# drfit_detected True
# Significant Accuracy Drop: True
# Significant F1 Score Drop: True
# Run completed and all data logged to MLflow!
