# %%
import fastdup

fd = fastdup.create(work_dir="/Users/ximenamoure/Desktop/fastdup3", input_dir="/Users/ximenamoure/Desktop/datasets")

# Step 1: Run FastDup
#fd.run(input_dir='/Users/ximenamoure/Desktop/drift_last/reference_dataset', work_dir='/Users/ximenamoure/Desktop/fastdup2')
# Out:
# fastdup By Visual Layer, Inc. 2024. All rights reserved.
#
# A fastdup dataset object was created!
#
# Input directory is set to "/Users/ximenamoure/Desktop/datasets"
# Work directory is set to "/Users/ximenamoure/Desktop/fastdup3"
#
# The next steps are:
#    1. Analyze your dataset with the .run() function of the dataset object
#    2. Interactively explore your data on your local machine with the .explore() function of the dataset object
#
# For more information, use help(fastdup) or check our documentation https://docs.visual-layer.com/docs/getting-started-with-fastdup.

# %%
fd.run()
# Out:
# fastdup By Visual Layer, Inc. 2024. All rights reserved.
# Initializing data [■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■] 100% Estimated: 0 Minutes
# [74424:8905480:20241002,194812.387013:ERROR crash_report_database_mac.mm:825] Failed to enumerate reports in directory /Users/ximenamoure/Desktop/fastdup2/processing/step_fastdup/images/tmp/.__fastdup-cache__/pending: Error Domain=NSCocoaErrorDomain Code=260 "The folder “pending” doesn’t exist." UserInfo={NSFilePath=/Users/ximenamoure/Desktop/fastdup2/processing/step_fastdup/images/tmp/.__fastdup-cache__/pending, NSUserStringVariant=(
#     Folder
# ), NSUnderlyingError=0x141f04aa0 {Error Domain=NSOSStatusErrorDomain Code=-43 "fnfErr: File not found"}}
# Creating visualization:  67%|██████▋   | 2/3 [04:57<02:53, 173.54s/it]
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ...

# %%
fd.explore()
# Out:
# The Visual Layer application was launched on your machine, you can find it on http://localhost:9990/dataset/643e0422-8056-40c5-9b3a-8ea44aefac98/data?page=1 in your web browser.
# Use Ctrl + C to stop the application server.
#
# For more information, use help(fastdup) or check our documentation https://docs.visual-layer.com/docs/getting-started-with-fastdup.
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages/pydantic/type_adapter.py:458: UserWarning: Pydantic serializer warnings:
#   Expected `dict[any, any]` but got `SeverityCount` - serialized value may not be as expected
#   Expected `dict[any, any]` but got `SeverityCount` - serialized value may not be as expected
#   Expected `dict[any, any]` but got `SeverityCount` - serialized value may not be as expected
#   return self.serializer.to_python(
# Thank you for using Visual Layer, the application server on your machine is now closed.
# Bye!

# %%
# Step 2: Visualize Similar Images (Component Gallery)
fd.vis.component_gallery()
# Out:
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-38025' coro=<Server.serve() done, defined at /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages/uvicorn/server.py:67> exception=KeyboardInterrupt()>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages/fastdup/fastdup_runner/fastdup_runner_server/fastdup_runner_server_launcher.py", line 130, in launch_server
#     run_server_process(port)
#   File "/opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages/fastdup/fastdup_runner/fastdup_runner_server/fastdup_runner_server_launcher.py", line 122, in run_server_process
#     uvicorn.run(app, host="0.0.0.0", port=port, log_level=settings.Settings.LOG_LEVEL)
#   File "/opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages/uvicorn/main.py", line 575, in run
#     server.run()
# ...

# %%
# Step 3: Visualize Outliers
fd.vis.outliers_gallery()
# Out:
# Generating gallery:   0%|          | 0/20 [00:00<?, ?it/s]
# Stored outliers visual view in  /Users/ximenamoure/Desktop/fastdup3/galleries/outliers.html
# ########################################################################################
# Would you like to see awesome visualizations for some of the most popular academic datasets?
# Click here to see and learn more: https://app.visual-layer.com/vl-datasets?utm_source=fastdup
# ########################################################################################
# 0

# %%
fd.vis.stats_gallery()
# Out:
# Generating gallery:   0%|          | 0/20 [00:00<?, ?it/s]
# Stored mean visual view in  /Users/ximenamoure/Desktop/fastdup3/galleries/mean.html
# ########################################################################################
# Would you like to see awesome visualizations for some of the most popular academic datasets?
# Click here to see and learn more: https://app.visual-layer.com/vl-datasets?utm_source=fastdup
# ########################################################################################
# 0

# %%
fd.summary()
# Out:
#  ########################################################################################
#
# Dataset Analysis Summary:
#
#     Dataset contains 115188 images
#     Valid images are 100.00% (115,188) of the data, invalid are 0.00% (0) of the data
#     Outliers: 6.26% (7,213) of images are possible outliers, and fall in the bottom 5.00% of similarity values.
#     For a detailed list of outliers, use `.outliers()`.
# ['Dataset contains 115188 images',
#  'Valid images are 100.00% (115,188) of the data, invalid are 0.00% (0) of the data',
#  'Outliers: 6.26% (7,213) of images are possible outliers, and fall in the bottom 5.00% of similarity values.',
#  'For a detailed list of outliers, use `.outliers()`.\n']

# %%
fd.outliers()
# Out:
#       outlier  nearest  distance                                                                                                filename_outlier  index_x error_code_outlier  is_valid_outlier  fd_index_outlier                                                                                                   filename_nearest  index_y error_code_nearest  is_valid_nearest  fd_index_nearest
# 0         193    17894  0.595585  /Users/ximenamoure/Desktop/datasets/reference_dataset/bb/TFG_sants-26-03-2023-Roger-2023-03-26_13-07-25_e1.png      193              VALID              True               193            /Users/ximenamoure/Desktop/datasets/reference_dataset/empty/WC2023_WC-Round1-2023-06-14_14-45-29_c3.png    17894              VALID              True             17894
# ...

# %%
f_vector = fd.feature_vector("/Users/ximenamoure/Desktop/drift_last/reference_dataset/bb/WC2023_WC-Round18-2023-07-04_19-24-21_d8.png")
# Out:
# fastdup By Visual Layer, Inc. 2024. All rights reserved.
# Initializing data [■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■] 100% Estimated: 0 Minutes
# Analysis complete. Use the .explore() function to interactively explore your data on your local machine.
#
# Alternatively, you can generate HTML-based galleries.
# For more information, use help(fastdup) or check our documentation https://docs.visual-layer.com/docs/getting-started-with-fastdup.

# %%
vector_size = len(f_vector)
print("Size of Feature Vector:", vector_size)
# Out:
# Size of Feature Vector: 2

# %%
f_vector[0].shape
# Out:
# (1, 576)
# [74424:8905480:20241002,201812.385961:ERROR crash_report_database_mac.mm:825] Failed to enumerate reports in directory /Users/ximenamoure/Desktop/fastdup2/processing/step_fastdup/images/tmp/.__fastdup-cache__/pending: Error Domain=NSCocoaErrorDomain Code=260 "The folder “pending” doesn’t exist." UserInfo={NSFilePath=/Users/ximenamoure/Desktop/fastdup2/processing/step_fastdup/images/tmp/.__fastdup-cache__/pending, NSUserStringVariant=(
#     Folder
# ), NSUnderlyingError=0x143d072e0 {Error Domain=NSOSStatusErrorDomain Code=-43 "fnfErr: File not found"}}
# ...
